# %% [markdown]
# # Imports

# %%
import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

from tqdm.notebook import tqdm as tqdm_notebook
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Data Preperation
#
# ```
# # Exploratory Data Analysis
# ```

# %%
print(torch.__version__)
# Out:
# 2.3.0+cu121

# %%
df = pd.read_csv("/content/household_power_consumption_household_power_consumption.csv")

# %%
df.head()
df.shape #9 columns: 8 independant & 1 dependant variable
# Out:
# (114219, 9)

# %%
# df.dtypes
df.infer_objects().dtypes
# Out:
# Date                      object
# Time                      object
# Global_active_power       object
# Global_reactive_power     object
# Voltage                   object
# Global_intensity          object
# Sub_metering_1            object
# Sub_metering_2            object
# Sub_metering_3           float64
# dtype: object

# %%
len(df.columns)
# Out:
# 9

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y')
df['Time'] = df['Time'].astype(str)
df['Time'] = pd.to_timedelta(df['Time'])
for i in range(2, len(df.columns)):
    try:
        df[df.columns[i]] = pd.to_numeric(df[df.columns[i]], errors='coerce')
        print(f"Converted column {i} to numeric")
    except Exception as e:
        print(f"Could not convert column {i}: {e}")
# Out:
# Converted column 2 to numeric
# Converted column 3 to numeric
# Converted column 4 to numeric
# Converted column 5 to numeric
# Converted column 6 to numeric
# Converted column 7 to numeric
# Converted column 8 to numeric

# %%
df.infer_objects().dtypes
# Out:
# Date                      datetime64[ns]
# Time                     timedelta64[ns]
# Global_active_power              float64
# Global_reactive_power            float64
# Voltage                          float64
# Global_intensity                 float64
# Sub_metering_1                   float64
# Sub_metering_2                   float64
# Sub_metering_3                   float64
# dtype: object

# %%
df.head()
# Out:
#         Date            Time  Global_active_power  Global_reactive_power  \
# 0 2007-01-01 0 days 00:00:00                2.580                  0.136
# 1 2007-01-01 0 days 00:01:00                2.552                  0.100
# 2 2007-01-01 0 days 00:02:00                2.550                  0.100
# 3 2007-01-01 0 days 00:03:00                2.550                  0.100
# 4 2007-01-01 0 days 00:04:00                2.554                  0.100
#
#    Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0   241.97              10.6             0.0             0.0             0.0
# 1   241.75              10.4             0.0             0.0             0.0
# 2   241.64              10.4             0.0             0.0             0.0
# 3   241.71              10.4             0.0             0.0             0.0
# 4   241.98              10.4             0.0             0.0             0.0

# %%
columns = list(df.columns)
columns.remove('Global_active_power')
columns.remove('Global_reactive_power')
columns.extend(['Global_active_power', 'Global_reactive_power'])

df = df[columns]

# %%
df.head()
# Out:
#         Date            Time  Voltage  Global_intensity  Sub_metering_1  \
# 0 2007-01-01 0 days 00:00:00   241.97              10.6             0.0
# 1 2007-01-01 0 days 00:01:00   241.75              10.4             0.0
# 2 2007-01-01 0 days 00:02:00   241.64              10.4             0.0
# 3 2007-01-01 0 days 00:03:00   241.71              10.4             0.0
# 4 2007-01-01 0 days 00:04:00   241.98              10.4             0.0
#
#    Sub_metering_2  Sub_metering_3  Global_active_power  Global_reactive_power
# 0             0.0             0.0                2.580                  0.136
# 1             0.0             0.0                2.552                  0.100
# 2             0.0             0.0                2.550                  0.100
# 3             0.0             0.0                2.550                  0.100
# 4             0.0             0.0                2.554                  0.100

# %%
df_group_1 = df[df['Sub_metering_1'] != 0][['Date', 'Time', 'Voltage', 'Global_intensity', 'Sub_metering_1', 'Global_active_power', 'Global_reactive_power']]
df_group_2 = df[df['Sub_metering_2'] != 0][['Date', 'Time', 'Voltage', 'Global_intensity', 'Sub_metering_2', 'Global_active_power', 'Global_reactive_power']]
df_group_3 = df[df['Sub_metering_3'] != 0][['Date', 'Time', 'Voltage', 'Global_intensity', 'Sub_metering_3', 'Global_active_power', 'Global_reactive_power']]

# %%
# df_sub_metering_1.describe()
# df_sub_metering_2.describe()
df_group_3.describe()
# Out:
#                                 Date                       Time       Voltage  \
# count                          44368                      44368  44364.000000
# mean   2007-04-15 01:25:33.213126400  0 days 13:52:35.183465560    238.986213
# min              2007-01-01 00:00:00            0 days 00:00:00     23.000000
# 25%              2007-01-28 00:00:00            0 days 09:30:00    237.080000
# 50%              2007-02-28 00:00:00            0 days 13:50:00    239.090000
# 75%              2007-07-02 00:00:00            0 days 18:52:00    241.100000
# max              2007-12-03 00:00:00            0 days 23:59:00    249.760000
# std                              NaN  0 days 05:46:08.219326181      3.251082
#
#        Global_intensity  Sub_metering_3  Global_active_power  \
# count      44363.000000    44363.000000         44364.000000
# mean          10.001145       17.410612             2.379899
# min            1.000000        1.000000             0.248000
# 25%            6.000000       17.000000             1.436000
# 50%            7.800000       18.000000             1.876000
# 75%           12.800000       18.000000             3.046000
# max           46.400000       20.000000            10.670000
# std            5.309725        1.253787             1.230224
#
#        Global_reactive_power
# count           44364.000000
# mean                0.136574
# min                 0.000000
# 25%                 0.046000
# 50%                 0.110000
# 75%                 0.210000
# max                 0.862000
# std                 0.124969

# %% [markdown]
# # Data Processing

# %% [markdown]
# # ARIMA

# %% [markdown]
# # SARIMA

# %% [markdown]
# # LSTM

# %%
def move_sliding_window(data, window_size, inputs_cols_indices, label_col_index):

    inputs = np.zeros((len(data) - window_size, window_size, len(inputs_cols_indices)))
    labels = np.zeros(len(data) - window_size)

    for i in range(window_size, len(data)):
        inputs[i - window_size] = data[i - window_size : i, inputs_cols_indices]
        labels[i - window_size] = data[i, label_col_index]
    inputs = inputs.reshape(-1, window_size, len(inputs_cols_indices))
    labels = labels.reshape(-1, 1)
    print(inputs.shape, labels.shape)

    return inputs, labels

# %%
label_col_index = 0
inputs_cols_indices = range(7)

window_size = 90

label_scalers = {}

train_x = []
test_x = {}
test_y = {}

# %% [markdown]
# # GRU
